# %% [markdown]
# <a href="https://colab.research.google.com/github/ally-ds/Tesorflow_Recycle_Image_Classfication/blob/master/Recycle_Image_Classfication_COLAB_Tuning_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#!unzip /content/drive/"My Drive"/dataset/recycle.zip  -d /content/drive/"My Drive"/

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import tensorflow as tf
assert tf.__version__.startswith('2')

import os
import numpy as np
import matplotlib.pyplot as plt

# %%
folder_name = '/content/drive/My Drive/dataset'
base_dir = os.path.join(folder_name)

# %%
IMAGE_SIZE = 224
BATCH_SIZE = 64

datagen = tf.keras.preprocessing.image.ImageDataGenerator(
    rescale=1./255,
    rotation_range=20,
    width_shift_range=0.1,
    height_shift_range=0.1,
    horizontal_flip=True,
    validation_split=0.1
)

train_generator = datagen.flow_from_directory(
    base_dir,
    target_size=(IMAGE_SIZE, IMAGE_SIZE),
    batch_size=BATCH_SIZE, 
    subset='training')

val_generator = datagen.flow_from_directory(
    base_dir,
    target_size=(IMAGE_SIZE, IMAGE_SIZE),
    batch_size=BATCH_SIZE, 
    subset='validation')

for image_batch, label_batch in train_generator:
  break
image_batch.shape, label_batch.shape
print(len(train_generator), len(val_generator))
# Out:
# Found 5142 images belonging to 4 classes.
# Found 570 images belonging to 4 classes.
# 81 9

# %%
print (train_generator.class_indices)
# Out:
# {'glass': 0, 'metal': 1, 'paper': 2, 'plastic': 3}

# %%
IMG_SHAPE = (IMAGE_SIZE, IMAGE_SIZE, 3)

# Create the base model from the pre-trained model MobileNet V2
base_model = tf.keras.applications.MobileNetV2(input_shape=IMG_SHAPE,
                                              include_top=False, 
                                              weights='imagenet')

# %%
base_model.trainable = False

# %%
model = tf.keras.Sequential([
  base_model,
  tf.keras.layers.Conv2D(32, 3, activation='relu'),
  tf.keras.layers.Dropout(0.2),
  tf.keras.layers.GlobalAveragePooling2D(),
  tf.keras.layers.Dense(4, activation='softmax')
])

# %%
model.compile(optimizer=tf.keras.optimizers.Adam(), 
              loss='categorical_crossentropy', 
              metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# mobilenetv2_1.00_224 (Model) (None, 7, 7, 1280)        2257984
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 5, 5, 32)          368672
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 5, 5, 32)          0
# _________________________________________________________________
# global_average_pooling2d_1 ( (None, 32)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 4)                 132
# =================================================================
# Total params: 2,626,788
# Trainable params: 368,804
# Non-trainable params: 2,257,984
# _________________________________________________________________

# %%
epochs = 10

history = model.fit(train_generator, 
                    steps_per_epoch=len(train_generator), 
                    epochs=epochs, 
                    validation_data=val_generator, 
                    validation_steps=len(val_generator))
# Out:
# Epoch 1/10
# 81/81 [==============================] - 68s 836ms/step - loss: 1.0688 - accuracy: 0.6813 - val_loss: 0.6778 - val_accuracy: 0.7491
# Epoch 2/10
# 81/81 [==============================] - 67s 827ms/step - loss: 0.6135 - accuracy: 0.7600 - val_loss: 0.6494 - val_accuracy: 0.7596
# Epoch 3/10
# 81/81 [==============================] - 67s 826ms/step - loss: 0.5710 - accuracy: 0.7750 - val_loss: 0.6660 - val_accuracy: 0.7316
# Epoch 4/10
# 81/81 [==============================] - 67s 825ms/step - loss: 0.5277 - accuracy: 0.7919 - val_loss: 0.6243 - val_accuracy: 0.7754
# Epoch 5/10
# 81/81 [==============================] - 67s 830ms/step - loss: 0.4775 - accuracy: 0.8092 - val_loss: 0.6225 - val_accuracy: 0.7596
# Epoch 6/10
# 81/81 [==============================] - 67s 824ms/step - loss: 0.4678 - accuracy: 0.8129 - val_loss: 0.6282 - val_accuracy: 0.7544
# Epoch 7/10
# 81/81 [==============================] - 67s 824ms/step - loss: 0.4299 - accuracy: 0.8279 - val_loss: 0.5788 - val_accuracy: 0.7860
# Epoch 8/10
# 81/81 [==============================] - 66s 821ms/step - loss: 0.4260 - accuracy: 0.8320 - val_loss: 0.6530 - val_accuracy: 0.7737
# Epoch 9/10
# 81/81 [==============================] - 67s 827ms/step - loss: 0.4039 - accuracy: 0.8392 - val_loss: 0.6275 - val_accuracy: 0.7684
# Epoch 10/10
# 81/81 [==============================] - 67s 824ms/step - loss: 0.3925 - accuracy: 0.8499 - val_loss: 0.6160 - val_accuracy: 0.7895

# %%
base_model.trainable = True
print("Number of layers in the base model: ", len(base_model.layers))
# Fine tune from this layer onwards
fine_tune_at = 140
# Freeze all the layers before the `fine_tune_at` layer
for layer in base_model.layers[:fine_tune_at]:
  layer.trainable =  False
  
model.compile(loss='categorical_crossentropy',
              optimizer = tf.keras.optimizers.Adam(1e-4),
              metrics=['accuracy'])
model.summary()
# Out:
# Number of layers in the base model:  155
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# mobilenetv2_1.00_224 (Model) (None, 7, 7, 1280)        2257984
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 5, 5, 32)          368672
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 5, 5, 32)          0
# _________________________________________________________________
# global_average_pooling2d_1 ( (None, 32)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 4)                 132
# =================================================================
# Total params: 2,626,788
# Trainable params: 1,408,804
# Non-trainable params: 1,217,984
# _________________________________________________________________

# %%
history_fine = model.fit(train_generator, 
                         epochs=10,
                         validation_data=val_generator)
# Out:
# Epoch 1/10
# 81/81 [==============================] - 67s 831ms/step - loss: 0.5342 - accuracy: 0.7927 - val_loss: 0.7390 - val_accuracy: 0.7719
# Epoch 2/10
# 81/81 [==============================] - 66s 820ms/step - loss: 0.3689 - accuracy: 0.8580 - val_loss: 0.7550 - val_accuracy: 0.7754
# Epoch 3/10
# 81/81 [==============================] - 67s 823ms/step - loss: 0.3151 - accuracy: 0.8810 - val_loss: 0.8490 - val_accuracy: 0.7895
# Epoch 4/10
# 81/81 [==============================] - 67s 827ms/step - loss: 0.2670 - accuracy: 0.8991 - val_loss: 0.9907 - val_accuracy: 0.7842
# Epoch 5/10
# 81/81 [==============================] - 68s 838ms/step - loss: 0.2359 - accuracy: 0.9092 - val_loss: 0.9144 - val_accuracy: 0.7632
# Epoch 6/10
# 81/81 [==============================] - 68s 839ms/step - loss: 0.2066 - accuracy: 0.9236 - val_loss: 0.9909 - val_accuracy: 0.7877
# Epoch 7/10
# 81/81 [==============================] - 67s 832ms/step - loss: 0.1831 - accuracy: 0.9323 - val_loss: 0.9061 - val_accuracy: 0.7930
# Epoch 8/10
# 81/81 [==============================] - 68s 842ms/step - loss: 0.1531 - accuracy: 0.9467 - val_loss: 0.9410 - val_accuracy: 0.7737
# Epoch 9/10
# 81/81 [==============================] - 68s 836ms/step - loss: 0.1466 - accuracy: 0.9467 - val_loss: 0.8490 - val_accuracy: 0.7930
# Epoch 10/10
# 81/81 [==============================] - 68s 838ms/step - loss: 0.1226 - accuracy: 0.9603 - val_loss: 0.8724 - val_accuracy: 0.7965

# %%
class_names = sorted(train_generator.class_indices.items(), key=lambda pair:pair[1])
class_names = np.array([key.title() for key, value in class_names])
class_names
# Out:
# array(['Glass', 'Metal', 'Paper', 'Plastic'], dtype='<U7')

# %%
predicted_batch = model.predict(image_batch)
predicted_id = np.argmax(predicted_batch, axis=-1)
predicted_label_batch = class_names[predicted_id]
label_id = np.argmax(label_batch, axis=-1)

# %%
plt.figure(figsize=(10,9))
plt.subplots_adjust(hspace=0.5)
for n in range(60):
  plt.subplot(10,6,n+1)
  plt.imshow(image_batch[n])
  color = "green" if predicted_id[n] == label_id[n] else "red"
  plt.title(predicted_label_batch[n].title(), color=color)
  plt.axis('off')
_ = plt.suptitle("Model predictions (green: correct, red: incorrect)")

# %%
test_folder_name = '/content/drive/My Drive/real_test'
test_dir = os.path.join(test_folder_name)

IMAGE_SIZE = 224
BATCH_SIZE = 64

test_datagen = tf.keras.preprocessing.image.ImageDataGenerator(
    rescale=1./255, 
    validation_split=0.2)

test_generator = test_datagen.flow_from_directory(
    test_dir,
    target_size=(IMAGE_SIZE, IMAGE_SIZE),
    batch_size=BATCH_SIZE)


for test_image_batch, test_label_batch in test_generator:
  break
test_image_batch.shape, test_label_batch.shape
# Out:
# Found 8 images belonging to 4 classes.
# ((8, 224, 224, 3), (8, 4))

# %%
real_batch = model.predict(test_image_batch)
real_id = np.argmax(real_batch, axis=-1)

real_label_batch = class_names[real_id]
real_label_id = np.argmax(test_label_batch, axis=-1)

# %%
plt.figure(figsize=(10,2))
plt.subplots_adjust(hspace=0.5)
for n in range(8):
  plt.subplot(1,8,n+1)
  plt.imshow(test_image_batch[n])
  color = "green" if real_id[n] == real_label_id[n] else "red"
  plt.title(real_label_batch[n].title(), color=color)
  plt.axis('off')
_ = plt.suptitle("Model predictions (green: correct, red: incorrect)")
